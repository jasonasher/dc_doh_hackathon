# %%
import pandas as pd
import numpy as np
import os

# %%
filename = '/Users/zeromh/ds/datakind/dc_doh_hackathon/data/311 service requests/2014-2016 311 Data/dc_311-2014.csv'
df = pd.read_csv(filename)
df.columns = df.columns.map(lambda x: x.lower())
df.head()
# Out:
#   servicerequestid servicepriority servicecode servicecodedescription  \
# 0      13-00301175         UNKNOWN       S0016           Alley Repair
# 1      13-00301176         UNKNOWN       S0276   Parking Meter Repair
# 2      13-00301177         UNKNOWN       S0471             Vacant Lot
# 3      13-00301178         UNKNOWN       S0276   Parking Meter Repair
# 4      13-00301179         UNKNOWN       S0261    Parking Enforcement
#
#   servicetypecode servicetypecodedescription      serviceorderdate  \
# 0        SISYINOD                       SIOD  2014-01-01T00:00:01Z
# 1        TRAOP001                        TOA  2014-01-01T00:09:16Z
# 2        SWMSWEEN     Sanitation Enforcement  2014-01-01T00:15:48Z
# 3        TRAOP001                        TOA  2014-01-01T00:30:29Z
# 4        PARKENFO        Parking Enforcement  2014-01-01T00:54:57Z
#
#   serviceorderstatus  servicecallcount agencyabbreviation        ...         \
# ...

# %%
rat_trubs = df[df.servicecode == 'S0311']
print rat_trubs.shape
rat_trubs.head()
# Out:
# (2363, 36)
#     servicerequestid servicepriority servicecode servicecodedescription  \
# 101      14-00000069         UNKNOWN       S0311          Rat Abatement
# 541      14-00000509         UNKNOWN       S0311          Rat Abatement
# 546      14-00000514         UNKNOWN       S0311          Rat Abatement
# 557      14-00000525         UNKNOWN       S0311          Rat Abatement
# 658      14-00000626         UNKNOWN       S0311          Rat Abatement
#
#     servicetypecode servicetypecodedescription      serviceorderdate  \
# 101        DEPAHEAL                        DOH  2014-01-01T21:20:08Z
# 541        DEPAHEAL                        DOH  2014-01-02T16:53:55Z
# 546        DEPAHEAL                        DOH  2014-01-02T16:56:12Z
# 557        DEPAHEAL                        DOH  2014-01-02T17:00:42Z
# 658        DEPAHEAL                        DOH  2014-01-02T18:11:37Z
#
#     serviceorderstatus  servicecallcount agencyabbreviation        ...         \
# ...

# %%
rat_trubs['serviceorderdate'] = pd.to_datetime(rat_trubs.serviceorderdate)
rat_trubs['week'] =  rat_trubs.serviceorderdate.dt.week
rat_trubs.head()
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#     servicerequestid servicepriority servicecode servicecodedescription  \
# 101      14-00000069         UNKNOWN       S0311          Rat Abatement
# 541      14-00000509         UNKNOWN       S0311          Rat Abatement
# 546      14-00000514         UNKNOWN       S0311          Rat Abatement
# 557      14-00000525         UNKNOWN       S0311          Rat Abatement
# 658      14-00000626         UNKNOWN       S0311          Rat Abatement
#
#     servicetypecode servicetypecodedescription    serviceorderdate  \
# 101        DEPAHEAL                        DOH 2014-01-01 21:20:08
# ...

# %%
rat_trubs.groupby('week').size()
# Out:
# week
# 1     23
# 2     28
# 3     41
# 4     18
# 5     27
# 6     32
# 7     13
# 8     28
# 9     37
# 10    20
# 11    43
# 12    22
# 13    28
# 14    44
# 15    56
# 16    60
# 17    79
# 18    53
# 19    73
# 20    57
# 21    51
# 22    39
# 23    80
# 24    62
# 25    65
# 26    68
# 27    44
# 28    55
# 29    57
# 30    74
# 31    69
# 32    75
# 33    67
# 34    60
# 35    57
# 36    49
# 37    59
# 38    67
# 39    57
# 40    49
# 41    42
# 42    40
# 43    44
# 44    55
# 45    31
# 46    41
# 47    23
# 48    20
# 49    31
# 50    20
# 51    19
# 52    11
# dtype: int64

# %%
rat_trubs.set_index('serviceorderdate', inplace=True)
rat_trubs.head()

# %%
# Out:
#                     servicerequestid servicepriority servicecode  \
# serviceorderdate
# 2014-01-01 21:20:08      14-00000069         UNKNOWN       S0311
# 2014-01-02 16:53:55      14-00000509         UNKNOWN       S0311
# 2014-01-02 16:56:12      14-00000514         UNKNOWN       S0311
# 2014-01-02 17:00:42      14-00000525         UNKNOWN       S0311
# 2014-01-02 18:11:37      14-00000626         UNKNOWN       S0311
#
#                     servicecodedescription servicetypecode  \
# serviceorderdate
# 2014-01-01 21:20:08          Rat Abatement        DEPAHEAL
# 2014-01-02 16:53:55          Rat Abatement        DEPAHEAL
# 2014-01-02 16:56:12          Rat Abatement        DEPAHEAL
# 2014-01-02 17:00:42          Rat Abatement        DEPAHEAL
# 2014-01-02 18:11:37          Rat Abatement        DEPAHEAL
#
#                     servicetypecodedescription serviceorderstatus  \
# serviceorderdate
# 2014-01-01 21:20:08                        DOH               OPEN
# ...
